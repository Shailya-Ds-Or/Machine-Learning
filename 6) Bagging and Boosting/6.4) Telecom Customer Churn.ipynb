# %% [markdown]
# # Telecom Customer Churn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import plot_confusion_matrix, classification_report

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Telco-Customer-Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0  7590-VHVEG  Female              0  ...          29.85        29.85     No
# 1  5575-GNVDE    Male              0  ...          56.95      1889.50     No
# 2  3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 3  7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 4  9237-HQITU  Female              0  ...          70.70       151.65    Yes
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df.shape
# Out:
# (7032, 21)

# %%
df["Churn"].value_counts()
# Out:
# No     5163
# Yes    1869
# Name: Churn, dtype: int64

# %%
plt.figure(figsize=(10,6), dpi= 150)

sns.boxplot(data=df, x= "Contract", y= "TotalCharges", hue= "Churn")

plt.show()

# %%
# Checking Correlation of Features to Target Variable:

# %%
# Dropping "customerID"

df = df.drop("customerID", axis= 1)

# %%
for col in df.columns:
    print(col)
    print(df[col].nunique())
# Out:
# gender
# 2
# SeniorCitizen
# 2
# Partner
# 2
# Dependents
# 2
# tenure
# 72
# PhoneService
# 2
# MultipleLines
# 3
# InternetService
# 3
# OnlineSecurity
# 3
# OnlineBackup
# 3
# DeviceProtection
# 3
# TechSupport
# 3
# StreamingTV
# 3
# StreamingMovies
# 3
# Contract
# 3
# PaperlessBilling
# 2
# PaymentMethod
# 4
# MonthlyCharges
# 1584
# TotalCharges
# 6530
# Churn
# 2

# %%
# We have Just 3 Numeric Columns: "tenure","MonthlyCharges" and "TotalCharges"
# "SeniorCitizen" shows as Numeric but it is Categorical.

# %%
# We need to convert all Categorical Features to Numeric by Label Encoding for Finding Correlation

df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
df.select_dtypes(include= "object").columns
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Churn'],
#       dtype='object')

# %%
cat_cols = list(df.select_dtypes(include= "object").columns)

# %%
cat_cols
# Out:
# ['gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Churn']

# %%
le = LabelEncoder()

for col in cat_cols:
    
    df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  ...  MonthlyCharges  TotalCharges  Churn
# 0       0              0        1  ...           29.85         29.85      0
# 1       1              0        0  ...           56.95       1889.50      0
# 2       1              0        0  ...           53.85        108.15      1
# 3       1              0        0  ...           42.30       1840.75      0
# 4       0              0        0  ...           70.70        151.65      1
#
# [5 rows x 20 columns]

# %%
corr = df.corr()

# %%
corr
# Out:
#                     gender  SeniorCitizen  ...  TotalCharges     Churn
# gender            1.000000      -0.001819  ...      0.000048 -0.008545
# SeniorCitizen    -0.001819       1.000000  ...      0.102411  0.150541
# Partner          -0.001379       0.016957  ...      0.319072 -0.149982
# Dependents        0.010349      -0.210550  ...      0.064653 -0.163128
# tenure            0.005285       0.015683  ...      0.825880 -0.354049
# PhoneService     -0.007515       0.008392  ...      0.113008  0.011691
# MultipleLines    -0.006908       0.146287  ...      0.453202  0.038043
# InternetService  -0.002236      -0.032160  ...     -0.175691 -0.047097
# OnlineSecurity   -0.014899      -0.127937  ...      0.254473 -0.289050
# OnlineBackup     -0.011920      -0.013355  ...      0.375556 -0.195290
# DeviceProtection  0.001348      -0.021124  ...      0.389066 -0.177883
# TechSupport      -0.006695      -0.151007  ...      0.276890 -0.282232
# ...

# %%
corr["Churn"]
# Out:
# gender             -0.008545
# SeniorCitizen       0.150541
# Partner            -0.149982
# Dependents         -0.163128
# tenure             -0.354049
# PhoneService        0.011691
# MultipleLines       0.038043
# InternetService    -0.047097
# OnlineSecurity     -0.289050
# OnlineBackup       -0.195290
# DeviceProtection   -0.177883
# TechSupport        -0.282232
# StreamingTV        -0.036303
# StreamingMovies    -0.038802
# Contract           -0.396150
# PaperlessBilling    0.191454
# PaymentMethod       0.107852
# MonthlyCharges      0.192858
# TotalCharges       -0.199484
# Churn               1.000000
# Name: Churn, dtype: float64

# %%
plt.figure(figsize=(12,6), dpi= 100)

sns.barplot(x= corr["Churn"].sort_values().iloc[:-1].index, y= corr["Churn"].sort_values().iloc[:-1].values)

plt.title("Feature Correlation with Churn")

plt.xticks(rotation= 90)

plt.show()

# %%
# Reation Between Monthly and Total Charges and Churn:

plt.figure(figsize=(12,6), dpi= 100)

sns.scatterplot(data=df, x= "MonthlyCharges", y= "TotalCharges", hue= "Churn")

plt.show()

# %%
# Tenure vs. Churn Percentage:

df.groupby(["Churn","tenure"]).count().T
# Out:
# Churn               0                                ...  1
# tenure             1    2    3   4   5   6   7   8   ... 65  66  67 68 69  70 71 72
# gender            233  115  106  93  69  70  80  81  ...  9  13  10  9  8  11  6  6
# SeniorCitizen     233  115  106  93  69  70  80  81  ...  9  13  10  9  8  11  6  6
# Partner           233  115  106  93  69  70  80  81  ...  9  13  10  9  8  11  6  6
# Dependents        233  115  106  93  69  70  80  81  ...  9  13  10  9  8  11  6  6
# PhoneService      233  115  106  93  69  70  80  81  ...  9  13  10  9  8  11  6  6
# MultipleLines     233  115  106  93  69  70  80  81  ...  9  13  10  9  8  11  6  6
# InternetService   233  115  106  93  69  70  80  81  ...  9  13  10  9  8  11  6  6
# OnlineSecurity    233  115  106  93  69  70  80  81  ...  9  13  10  9  8  11  6  6
# OnlineBackup      233  115  106  93  69  70  80  81  ...  9  13  10  9  8  11  6  6
# ...

# %%
no_churn = df.groupby(["Churn","tenure"]).count().T[0].loc["gender"]

# %%
yes_churn = df.groupby(["Churn","tenure"]).count().T[1].loc["gender"]

# %%
no_churn
# Out:
# tenure
# 1     233
# 2     115
# 3     106
# 4      93
# 5      69
#      ...
# 68     91
# 69     87
# 70    108
# 71    164
# 72    356
# Name: gender, Length: 72, dtype: int64

# %%
yes_churn
# Out:
# tenure
# 1     380
# 2     123
# 3      94
# 4      83
# 5      64
#      ...
# 68      9
# 69      8
# 70     11
# 71      6
# 72      6
# Name: gender, Length: 72, dtype: int64

# %%
churn_percentage = 100 * yes_churn / (yes_churn + no_churn)

# %%
churn_percentage
# Out:
# tenure
# 1     61.990212
# 2     51.680672
# 3     47.000000
# 4     47.159091
# 5     48.120301
#         ...
# 68     9.000000
# 69     8.421053
# 70     9.243697
# 71     3.529412
# 72     1.657459
# Name: gender, Length: 72, dtype: float64

# %%
plt.figure(figsize=(12,6), dpi= 100)

churn_percentage.plot()

plt.show()

# %% [markdown]
# ### Train Test Split:

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  ...  MonthlyCharges  TotalCharges  Churn
# 0       0              0        1  ...           29.85         29.85      0
# 1       1              0        0  ...           56.95       1889.50      0
# 2       1              0        0  ...           53.85        108.15      1
# 3       1              0        0  ...           42.30       1840.75      0
# 4       0              0        0  ...           70.70        151.65      1
#
# [5 rows x 20 columns]

# %%
# Reading Data From File again as we want to create Dummy Variables for Categorical Variables

df = pd.read_csv("Telco-Customer-Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0  7590-VHVEG  Female              0  ...          29.85        29.85     No
# 1  5575-GNVDE    Male              0  ...          56.95      1889.50     No
# 2  3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 3  7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 4  9237-HQITU  Female              0  ...          70.70       151.65    Yes
#
# [5 rows x 21 columns]

# %%
df = df.drop("customerID", axis= 1)

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner  ... MonthlyCharges  TotalCharges Churn
# 0  Female              0     Yes  ...          29.85         29.85    No
# 1    Male              0      No  ...          56.95       1889.50    No
# 2    Male              0      No  ...          53.85        108.15   Yes
# 3    Male              0      No  ...          42.30       1840.75    No
# 4  Female              0      No  ...          70.70        151.65   Yes
#
# [5 rows x 20 columns]

# %%
df["SeniorCitizen"].value_counts()
# Out:
# 0    5890
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %%
# Converting "SeniorCitizen" to Categorcal:

df["SeniorCitizen"] = df["SeniorCitizen"].map({0: "No", 1: "Yes"})

# %%
df["SeniorCitizen"].value_counts()
# Out:
# No     5890
# Yes    1142
# Name: SeniorCitizen, dtype: int64

# %%
df.head()
# Out:
#    gender SeniorCitizen Partner  ... MonthlyCharges  TotalCharges Churn
# 0  Female            No     Yes  ...          29.85         29.85    No
# 1    Male            No      No  ...          56.95       1889.50    No
# 2    Male            No      No  ...          53.85        108.15   Yes
# 3    Male            No      No  ...          42.30       1840.75    No
# 4  Female            No      No  ...          70.70        151.65   Yes
#
# [5 rows x 20 columns]

# %%
sc = StandardScaler()

# %%
# Scalling Numeric Columns:

df["tenure"] = sc.fit_transform(df[["tenure"]])
df["MonthlyCharges"] = sc.fit_transform(df[["MonthlyCharges"]])
df["TotalCharges"] = sc.fit_transform(df[["TotalCharges"]])

# %%
df.head()
# Out:
#    gender SeniorCitizen Partner  ... MonthlyCharges  TotalCharges Churn
# 0  Female            No     Yes  ...      -1.161694     -0.994194    No
# 1    Male            No      No  ...      -0.260878     -0.173740    No
# 2    Male            No      No  ...      -0.363923     -0.959649   Yes
# 3    Male            No      No  ...      -0.747850     -0.195248    No
# 4  Female            No      No  ...       0.196178     -0.940457   Yes
#
# [5 rows x 20 columns]

# %%
x = df.drop("Churn", axis= 1)

x = pd.get_dummies(x, drop_first= True)

# %%
x.head()
# Out:
#      tenure  ...  PaymentMethod_Mailed check
# 0 -1.280248  ...                           0
# 1  0.064303  ...                           1
# 2 -1.239504  ...                           1
# 3  0.512486  ...                           0
# 4 -1.239504  ...                           0
#
# [5 rows x 30 columns]

# %%
x.shape
# Out:
# (7032, 30)

# %%
y = df["Churn"]

# %%
y.head()
# Out:
# 0     No
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# Name: Churn, dtype: object

# %%
y.shape
# Out:
# (7032,)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2, random_state= 42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (5625, 30)
# (1407, 30)
# (5625,)
# (1407,)

# %% [markdown]
# ### Model Fitting and Evaluation Function:

# %%
def model_fit_eval(model, param_dict):
    
    grid_model = GridSearchCV(estimator= model, param_grid= param_dict, cv=5)
    
    grid_model.fit(x_train, y_train)
    
    print("Best Parameters:\n")
    
    print(grid_model.best_params_)
    
    print("\n")
    
    pred = grid_model.predict(x_test)
    
    print(classification_report(y_test, pred))
    
    plot_confusion_matrix(grid_model.best_estimator_, x_test, y_test)

# %% [markdown]
# ### Models:

# %% [markdown]
# #### 1) Logisctic Regression:

# %%
log_model = LogisticRegression()

# %%
param_dict = {"penalty" : ["l1", "l2", "elasticnet"], "C" : np.logspace(0, 5, 10),
                                     "l1_ratio" : [0, 0.01, 0.1, 0.25, 0.5, 0.75, 0.9, 0.99, 1]}

# %%
model_fit_eval(log_model, param_dict)
# Out:
# Best Parameters:
#
# {'C': 46.4158883361278, 'l1_ratio': 0, 'penalty': 'l2'}
#
#
#               precision    recall  f1-score   support
#
#           No       0.84      0.89      0.86      1033
#          Yes       0.62      0.52      0.57       374
#
#     accuracy                           0.79      1407
#    macro avg       0.73      0.70      0.71      1407
# weighted avg       0.78      0.79      0.78      1407

# %% [markdown]
# #### 2) Support Vector Machine:

# %%
svm_model = SVC()

# %%
param_dict = {"kernel" : ["linear", "rbf", "poly", "sigmoid"],
             "C" : [0.01, 0,1, 1, 10, 100],
             "degree" : [1,2,3], "gamma" : ["scale", "auto"]}

# %%
model_fit_eval(svm_model, param_dict)
# Out:
# Best Parameters:
#
# {'C': 1, 'degree': 1, 'gamma': 'scale', 'kernel': 'rbf'}
#
#
#               precision    recall  f1-score   support
#
#           No       0.83      0.91      0.86      1033
#          Yes       0.65      0.47      0.54       374
#
#     accuracy                           0.79      1407
#    macro avg       0.74      0.69      0.70      1407
# weighted avg       0.78      0.79      0.78      1407

# %% [markdown]
# #### 3) KNN:

# %%
knn_model = KNeighborsClassifier()

# %%
param_dict = {"n_neighbors" : list(range(1,15)), 
             "metric" : ["euclidean", "cosine", "manhattan","minkowski"]}

# %%
model_fit_eval(knn_model, param_dict)
# Out:
# Best Parameters:
#
# {'metric': 'manhattan', 'n_neighbors': 14}
#
#
#               precision    recall  f1-score   support
#
#           No       0.83      0.87      0.85      1033
#          Yes       0.58      0.49      0.53       374
#
#     accuracy                           0.77      1407
#    macro avg       0.71      0.68      0.69      1407
# weighted avg       0.76      0.77      0.76      1407

# %% [markdown]
# #### 4) Decision Tree:

# %%
dt_model = DecisionTreeClassifier()

# %%
param_dict = {"criterion" : ["gini", "entropy"],
             "splitter" : ["best","random"]}

# %%
model_fit_eval(dt_model, param_dict)
# Out:
# Best Parameters:
#
# {'criterion': 'entropy', 'splitter': 'best'}
#
#
#               precision    recall  f1-score   support
#
#           No       0.82      0.80      0.81      1033
#          Yes       0.48      0.52      0.50       374
#
#     accuracy                           0.72      1407
#    macro avg       0.65      0.66      0.66      1407
# weighted avg       0.73      0.72      0.73      1407

# %% [markdown]
# #### 5) Random Forest:

# %%
rf_model = RandomForestClassifier()

# %%
param_dict = {"n_estimators" : [1,10,50,100,200],
             "criterion" : ["gini", "entropy"],
             "max_features" : [2,3,4],
             "bootstrap" : [True, False],
             "oob_score" : [True,False]}

# %%
model_fit_eval(rf_model, param_dict)
# Out:
# Best Parameters:
#
# {'bootstrap': True, 'criterion': 'entropy', 'max_features': 4, 'n_estimators': 200, 'oob_score': True}
#
#
#               precision    recall  f1-score   support
#
#           No       0.82      0.90      0.86      1033
#          Yes       0.62      0.47      0.53       374
#
#     accuracy                           0.78      1407
#    macro avg       0.72      0.68      0.69      1407
# weighted avg       0.77      0.78      0.77      1407

# %% [markdown]
# #### 6) AdaBoost:

# %%
adb_model = AdaBoostClassifier()

# %%
param_dict = {"n_estimators" : [10,50,100],
             "learning_rate" : [0.01, 0.1, 1, 10],
             "algorithm" : ["SAMME","SAMME.R"]}

# %%
model_fit_eval(adb_model, param_dict)
# Out:
# Best Parameters:
#
# {'algorithm': 'SAMME', 'learning_rate': 1, 'n_estimators': 50}
#
#
#               precision    recall  f1-score   support
#
#           No       0.83      0.90      0.87      1033
#          Yes       0.65      0.49      0.56       374
#
#     accuracy                           0.79      1407
#    macro avg       0.74      0.70      0.71      1407
# weighted avg       0.78      0.79      0.78      1407

# %% [markdown]
# #### 7) Gradient Boost:

# %%
gb_model = GradientBoostingClassifier()

# %%
param_dict = {"n_estimators": [1,5,10,50,100],
              "max_depth": [3,4,5,6],
             "max_features": ["auto", "sqrt", "log2"]}

# %%
model_fit_eval(gb_model, param_dict)
# Out:
# Best Parameters:
#
# {'max_depth': 4, 'max_features': 'log2', 'n_estimators': 50}
#
#
#               precision    recall  f1-score   support
#
#           No       0.83      0.91      0.87      1033
#          Yes       0.66      0.47      0.55       374
#
#     accuracy                           0.79      1407
#    macro avg       0.74      0.69      0.71      1407
# weighted avg       0.78      0.79      0.78      1407

# %% [markdown]
# #### 8) XGBoost:

# %%
xgb_model = XGBClassifier()

# %%
param_dict = {
    'n_estimators': [1,10,50,75,100],
    'max_depth': range(1, 5),
    'learning_rate': [.4, .45, .5, .55, .6],
    'colsample_bytree': [.6, .7, .8, .9, 1]}

# %%
model_fit_eval(xgb_model, param_dict)
# Out:
# [13:04:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:04:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:04:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...
